# %% [markdown]
# # **Pandas in python**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()   ### top 5 data
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.head(2)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0

# %%
df.describe()     ##stastically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()    ## Data Type Information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:4, :3]    ### iloc[row_range , column_range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3 , ['cgpa' , 'placed']]    ## loc[row_range , column_names]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty    ### it return true if there any missing data in dataframe
b
# Out:
# False

# %%
df.isnull().sum()    ##for checking missing values.
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()    ### for remove missing row.
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i = df.ndim    ### number of axes (it is 2)
i
# Out:
# 2

# %%
t = df.shape    #### shape = n(rows) , n(columns)
t
# Out:
# (100, 3)

# %%
d = df.size    ### row count * column count
d
# Out:
# 300

# %%
a = df.values    ### get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
# x = df.astype(int)   # type conversion
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
## dataframe is mutable

# t = df.add(4)
t
df['cgpa'] = df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
g = df.filter(items = ['cgpa' , 'placed'])
g

df[['cgpa' , 'placed']]
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
s = df.copy()   ### there will be no change in the original one if we will use copy method.
s
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
s['input'] = 2
s
# Out:
#     cgpa  resume_score  placed  input
# 0     12          6.52       1      2
# 1     10          5.17       0      2
# 2     12          8.86       1      2
# 3     10          7.27       1      2
# 4     11          7.30       1      2
# ..   ...           ...     ...    ...
# 95    10          6.38       0      2
# 96    12          7.76       1      2
# 97    10          7.78       0      2
# 98    12          5.63       1      2
# 99    10          6.61       0      2
#
# [100 rows x 4 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
p = df.rename(columns = {'cgpa':'updated_cgpa' , 'resume_score':'semester_marks'})   ## how to rename a column
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             12            6.52       1
# 1             10            5.17       0
# 2             12            8.86       1
# 3             10            7.27       1
# 4             11            7.30       1
# ..           ...             ...     ...
# 95            10            6.38       0
# 96            12            7.76       1
# 97            10            7.78       0
# 98            12            5.63       1
# 99            10            6.61       0
#
# [100 rows x 3 columns]

# %%
## How can we export our data into Excel?

# %%
#go to files in left corner --> click to files ---> copy triple dots of
#sample data folder --> paste it into to_csv

df.to_csv("/content/sample_data/student_data.csv")

# %%
### questions for second half of day 3

# %%
# Q.11 Given the strings "Python is awesome and fun",

# find the Length of the Longest word.

def find_longest_word_length(s):
    max_length = 0
    word_length = 0
    for char in s:
        if char == " ":
            if word_length > max_length:
                max_length = word_length
            word_length = 0
        else:
            word_length += 1
    if word_length > max_length:
        max_length = word_length
    return max_length

s = "Python is awesome and fun"
print(find_longest_word_length(s))
# Out:
# 7

# %%
#Q.12 Replace all occurrences of "apple" with "orange" in the
#strings "apple pie and apple juice".

def replace_word(s, old_word, new_word):
    result = ""
    word = ""
    for char in s:
        if char == " ":  # Check for space indicating the end of a word
            if word == old_word:  # If the current word matches old_word
                result += new_word  # Add new_word to the result
            else:
                result += word  # Add the original word to the result
            result += " "  # Add the space
            word = ""  # Reset the word
        else:
            word += char  # Build the current word
    # Handle the last word
    if word == old_word:
        result += new_word
    else:
        result += word
    return result

s = "apple pie and apple juice"
print(replace_word(s, "apple", "orange"))
# Out:
# orange pie and orange juice

# %%
# Q.13 How would you check if the strings si "Hello" and

# s2 "hello" are equal, ignoring case?

def strings_equal_ignore_case(s1, s2):
    if len(s1) != len(s2):
        return False
    for i in range(len(s1)):
        if s1[i].lower() != s2[i].lower():
            return False
    return True

s1 = "Hello"
s2 = "hello"
print(strings_equal_ignore_case(s1, s2))
# Out:
# True

# %%
# Q.14 From the strings "abcdefgh",

# extract every second character (1.e., "bdfh").

def extract_second_characters(s):
    result = ""
    for i in range(1, len(s), 2):
        result += s[i]
    return result

s = "abcdefgh"
print(extract_second_characters(s))
# Out:
# bdfh

# %%
# Q.15 Given the string s = "12345", how would you check if it

# contains only numeric digits?


def is_numeric(s):
    for char in s:
        if not ('0' <= char <= '9'):
            return False
    return True

s = "12345"
print(is_numeric(s))
# Out:
# True

# %%
# Q.16 Convert the strings "python is fun" so that the

# first letter of each word is capitalized.

def capitalize_first_letter_of_each_word(s):
    return s.title()

s = "python is fun"
print(capitalize_first_letter_of_each_word(s))
# Out:
# Python Is Fun
